# %%
import pandas as pd
df_amazon = pd.read_csv("Amazon.csv")
df_amazon.columns
# Out:
# C:\Users\quint\AppData\Local\Temp\ipykernel_9464\2277701326.py:2: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_amazon = pd.read_csv("Amazon.csv")
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
df_amazon['Unnamed: 22'].tail()
# Out:
# 128970    False
# 128971    False
# 128972    False
# 128973    False
# 128974    False
# Name: Unnamed: 22, dtype: object

# %%
df_amazon['Unnamed: 22'].unique()
# Out:
# array([nan, False], dtype=object)

# %%
df_amazon = df_amazon.drop(columns=['Unnamed: 22'])

# %%
df_amazon['Sales Channel '].nunique()
# Out:
# 2

# %%
df_amazon = df_amazon.drop(columns=['Sales Channel '])

# %%
df_amazon = df_amazon.drop(columns=['index'])

# %%
df_amazon.head()
# Out:
#               Order ID      Date                        Status Fulfilment  \
# 0  405-8078784-5731545  04-30-22                     Cancelled   Merchant
# 1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2  404-0687676-7273146  04-30-22                       Shipped     Amazon
# 3  403-9615377-8133951  04-30-22                     Cancelled   Merchant
# 4  407-1069790-7240320  04-30-22                       Shipped     Amazon
#
#   ship-service-level    Style              SKU       Category Size  \
# 0           Standard   SET389   SET389-KR-NP-S            Set    S
# 1           Standard  JNE3781  JNE3781-KR-XXXL          kurta  3XL
# 2          Expedited  JNE3371    JNE3371-KR-XL          kurta   XL
# 3           Standard    J0341       J0341-DR-L  Western Dress    L
# 4          Expedited  JNE3671  JNE3671-TU-XXXL            Top  3XL
#
#          ASIN  ... Qty  currency  Amount    ship-city   ship-state  \
# 0  B09KXVBD7Z  ...   0       INR  647.62       MUMBAI  MAHARASHTRA
# 1  B09K3WFS32  ...   1       INR  406.00    BENGALURU    KARNATAKA
# 2  B07WV4JV4D  ...   1       INR  329.00  NAVI MUMBAI  MAHARASHTRA
# 3  B099NRCT7B  ...   0       INR  753.33   PUDUCHERRY   PUDUCHERRY
# 4  B098714BZP  ...   1       INR  574.00      CHENNAI   TAMIL NADU
#
#   ship-postal-code  ship-country  \
# 0         400081.0            IN
# 1         560085.0            IN
# 2         410210.0            IN
# 3         605008.0            IN
# 4         600073.0            IN
#
#                                        promotion-ids    B2B  fulfilled-by
# 0                                                NaN  False     Easy Ship
# 1  Amazon PLCC Free-Financing Universal Merchant ...  False     Easy Ship
# 2       IN Core Free Shipping 2015/04/08 23-48-5-108   True           NaN
# 3                                                NaN  False     Easy Ship
# 4                                                NaN  False           NaN
#
# [5 rows x 21 columns]

# %%
print(df_amazon.columns.tolist())
# Out:
# ['Order ID', 'Date', 'Status', 'Fulfilment', 'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN', 'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids', 'B2B', 'fulfilled-by']

# %%
df_amazon['currency'].unique()
# Out:
# array(['INR', nan], dtype=object)

# %%
df_amazon = df_amazon.drop(columns=['currency'])

# %%
df_amazon['fulfilled-by'].unique()
# Out:
# array(['Easy Ship', nan], dtype=object)

# %%
df_amazon = df_amazon.drop(columns=['ship-country'])

# %%
df_amazon = df_amazon.drop(columns=['fulfilled-by'])

# %%
df_amazon.dtypes
# Out:
# Order ID               object
# Date                   object
# Status                 object
# Fulfilment             object
# ship-service-level     object
# Style                  object
# SKU                    object
# Category               object
# Size                   object
# ASIN                   object
# Courier Status         object
# Qty                     int64
# Amount                float64
# ship-city              object
# ship-state             object
# ship-postal-code      float64
# promotion-ids          object
# B2B                      bool
# dtype: object

# %%
df_amazon.shape
# Out:
# (128975, 18)

# %%
df_amazon.isnull().sum()
# Out:
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# promotion-ids         49153
# B2B                       0
# dtype: int64

# %%
#df_amazon = df_amazon.dropna()

# %%
df_amazon.isnull().sum()
# Out:
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# promotion-ids         49153
# B2B                       0
# dtype: int64

# %%
df_amazon.shape
# Out:
# (128975, 18)

# %%
df_amazon.isnull()
# Out:
#         Order ID   Date  Status  Fulfilment  ship-service-level  Style    SKU  \
# 0          False  False   False       False               False  False  False
# 1          False  False   False       False               False  False  False
# 2          False  False   False       False               False  False  False
# 3          False  False   False       False               False  False  False
# 4          False  False   False       False               False  False  False
# ...          ...    ...     ...         ...                 ...    ...    ...
# 128970     False  False   False       False               False  False  False
# 128971     False  False   False       False               False  False  False
# 128972     False  False   False       False               False  False  False
# 128973     False  False   False       False               False  False  False
# 128974     False  False   False       False               False  False  False
#
#         Category   Size   ASIN  Courier Status    Qty  Amount  ship-city  \
# 0          False  False  False            True  False   False      False
# 1          False  False  False           False  False   False      False
# 2          False  False  False           False  False   False      False
# 3          False  False  False            True  False   False      False
# 4          False  False  False           False  False   False      False
# ...          ...    ...    ...             ...    ...     ...        ...
# 128970     False  False  False           False  False   False      False
# 128971     False  False  False           False  False   False      False
# 128972     False  False  False           False  False   False      False
# 128973     False  False  False           False  False   False      False
# 128974     False  False  False           False  False   False      False
#
#         ship-state  ship-postal-code  promotion-ids    B2B
# 0            False             False           True  False
# 1            False             False          False  False
# 2            False             False          False  False
# 3            False             False           True  False
# 4            False             False           True  False
# ...            ...               ...            ...    ...
# 128970       False             False           True  False
# 128971       False             False          False  False
# 128972       False             False           True  False
# 128973       False             False          False  False
# 128974       False             False          False  False
#
# [128975 rows x 18 columns]

# %%
df_amazon.head()
# Out:
#               Order ID      Date                        Status Fulfilment  \
# 0  405-8078784-5731545  04-30-22                     Cancelled   Merchant
# 1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2  404-0687676-7273146  04-30-22                       Shipped     Amazon
# 3  403-9615377-8133951  04-30-22                     Cancelled   Merchant
# 4  407-1069790-7240320  04-30-22                       Shipped     Amazon
#
#   ship-service-level    Style              SKU       Category Size  \
# 0           Standard   SET389   SET389-KR-NP-S            Set    S
# 1           Standard  JNE3781  JNE3781-KR-XXXL          kurta  3XL
# 2          Expedited  JNE3371    JNE3371-KR-XL          kurta   XL
# 3           Standard    J0341       J0341-DR-L  Western Dress    L
# 4          Expedited  JNE3671  JNE3671-TU-XXXL            Top  3XL
#
#          ASIN Courier Status  Qty  Amount    ship-city   ship-state  \
# 0  B09KXVBD7Z            NaN    0  647.62       MUMBAI  MAHARASHTRA
# 1  B09K3WFS32        Shipped    1  406.00    BENGALURU    KARNATAKA
# 2  B07WV4JV4D        Shipped    1  329.00  NAVI MUMBAI  MAHARASHTRA
# 3  B099NRCT7B            NaN    0  753.33   PUDUCHERRY   PUDUCHERRY
# 4  B098714BZP        Shipped    1  574.00      CHENNAI   TAMIL NADU
#
#    ship-postal-code                                      promotion-ids    B2B
# 0          400081.0                                                NaN  False
# 1          560085.0  Amazon PLCC Free-Financing Universal Merchant ...  False
# 2          410210.0       IN Core Free Shipping 2015/04/08 23-48-5-108   True
# 3          605008.0                                                NaN  False
# 4          600073.0                                                NaN  False

# %%
df_amazon.columns
# Out:
# Index(['Order ID', 'Date', 'Status', 'Fulfilment', 'ship-service-level',
#        'Style', 'SKU', 'Category', 'Size', 'ASIN', 'Courier Status', 'Qty',
#        'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'promotion-ids', 'B2B'],
#       dtype='object')

# %%
df_amazon.isnull().sum()
# Out:
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# promotion-ids         49153
# B2B                       0
# dtype: int64

# %%
df_amazon.shape
# Out:
# (128975, 18)

# %%
df_amazon = df_amazon.drop(columns=['promotion-ids'])

# %%
df_amazon.shape
# Out:
# (128975, 17)

# %%
df_amazon.isnull().sum()
# Out:
# Order ID                 0
# Date                     0
# Status                   0
# Fulfilment               0
# ship-service-level       0
# Style                    0
# SKU                      0
# Category                 0
# Size                     0
# ASIN                     0
# Courier Status        6872
# Qty                      0
# Amount                7795
# ship-city               33
# ship-state              33
# ship-postal-code        33
# B2B                      0
# dtype: int64

# %%
df_amazon = df_amazon.dropna()

# %%
df_amazon
# Out:
#                    Order ID      Date                        Status  \
# 1       171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  04-30-22                       Shipped
# 4       407-1069790-7240320  04-30-22                       Shipped
# 5       404-1490984-4578765  04-30-22                       Shipped
# 6       408-5748499-6859555  04-30-22                       Shipped
# ...                     ...       ...                           ...
# 128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  408-7436540-8728312  05-31-22                       Shipped
#
#        Fulfilment ship-service-level    Style              SKU       Category  \
# 1        Merchant           Standard  JNE3781  JNE3781-KR-XXXL          kurta
# 2          Amazon          Expedited  JNE3371    JNE3371-KR-XL          kurta
# 4          Amazon          Expedited  JNE3671  JNE3671-TU-XXXL            Top
# 5          Amazon          Expedited   SET264  SET264-KR-NP-XL            Set
# 6          Amazon          Expedited    J0095      J0095-SET-L            Set
# ...           ...                ...      ...              ...            ...
# 128970     Amazon          Expedited  JNE3697    JNE3697-KR-XL          kurta
# 128971     Amazon          Expedited   SET401   SET401-KR-NP-M            Set
# 128972     Amazon          Expedited    J0157     J0157-DR-XXL  Western Dress
# 128973     Amazon          Expedited    J0012     J0012-SKD-XS            Set
# 128974     Amazon          Expedited    J0003      J0003-SET-S            Set
#
#        Size        ASIN Courier Status  Qty  Amount    ship-city  \
# 1       3XL  B09K3WFS32        Shipped    1   406.0    BENGALURU
# 2        XL  B07WV4JV4D        Shipped    1   329.0  NAVI MUMBAI
# 4       3XL  B098714BZP        Shipped    1   574.0      CHENNAI
# 5        XL  B08YN7XDSG        Shipped    1   824.0    GHAZIABAD
# 6         L  B08CMHNWBN        Shipped    1   653.0   CHANDIGARH
# ...     ...         ...            ...  ...     ...          ...
# 128970   XL  B098112V2V        Shipped    1   517.0    HYDERABAD
# 128971    M  B09VC6KHX8        Shipped    1   999.0     GURUGRAM
# 128972  XXL  B0982YZ51B        Shipped    1   690.0    HYDERABAD
# 128973   XS  B0894Y2NJQ        Shipped    1  1199.0        Halol
# 128974    S  B0894X27FC        Shipped    1   696.0       Raipur
#
#            ship-state  ship-postal-code    B2B
# 1           KARNATAKA          560085.0  False
# 2         MAHARASHTRA          410210.0   True
# 4          TAMIL NADU          600073.0  False
# 5       UTTAR PRADESH          201102.0  False
# 6          CHANDIGARH          160036.0  False
# ...               ...               ...    ...
# 128970      TELANGANA          500013.0  False
# 128971        HARYANA          122004.0  False
# 128972      TELANGANA          500049.0  False
# 128973        Gujarat          389350.0  False
# 128974   CHHATTISGARH          492014.0  False
#
# [116016 rows x 17 columns]

# %%
df_amazon["Date"] = pd.to_datetime(df_amazon["Date"], errors="coerce")
# Out:
# C:\Users\quint\AppData\Local\Temp\ipykernel_9464\3621826320.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_amazon["Date"] = pd.to_datetime(df_amazon["Date"], errors="coerce")

# %%
df_amazon.dtypes
# Out:
# Order ID                      object
# Date                  datetime64[ns]
# Status                        object
# Fulfilment                    object
# ship-service-level            object
# Style                         object
# SKU                           object
# Category                      object
# Size                          object
# ASIN                          object
# Courier Status                object
# Qty                            int64
# Amount                       float64
# ship-city                     object
# ship-state                    object
# ship-postal-code             float64
# B2B                             bool
# dtype: object

# %%
df_amazon[df_amazon.duplicated(subset='Order ID', keep=False)]
# Out:
#                    Order ID       Date   Status Fulfilment ship-service-level  \
# 37      403-4367956-2849158 2022-04-30  Shipped     Amazon          Expedited
# 38      403-4367956-2849158 2022-04-30  Shipped     Amazon          Expedited
# 61      404-2262140-4696366 2022-04-30  Shipped     Amazon          Expedited
# 62      404-2262140-4696366 2022-04-30  Shipped     Amazon          Expedited
# 79      408-4069830-3819562 2022-04-30  Shipped     Amazon          Expedited
# ...                     ...        ...      ...        ...                ...
# 128930  407-8519205-5064368 2022-05-31  Shipped     Amazon          Expedited
# 128941  403-3035549-4142738 2022-05-31  Shipped     Amazon          Expedited
# 128942  403-3035549-4142738 2022-05-31  Shipped     Amazon          Expedited
# 128952  404-8878574-4524358 2022-05-31  Shipped     Amazon          Expedited
# 128953  404-8878574-4524358 2022-05-31  Shipped     Amazon          Expedited
#
#           Style                 SKU Category Size        ASIN Courier Status  \
# 37      JNE3787        JNE3787-KR-S    kurta    S  B09RKBXM5B        Shipped
# 38      JNE3543        JNE3543-KR-S    kurta    S  B08HHJP41L        Shipped
# 61      JNE2270  JNE2270-KR-487-A-M    kurta    M  B07H7FZD32        Shipped
# 62      JNE3579        JNE3579-KR-M    kurta    M  B08QGK2BS2        Shipped
# 79       SET288   SET288-KR-NP-XXXL      Set  3XL  B09M6STTBC        Shipped
# ...         ...                 ...      ...  ...         ...            ...
# 128930   SET324     SET324-KR-NP-XL      Set   XL  B09NQ4QS13        Shipped
# 128941    J0118        J0118-TP-XXL      Top  XXL  B08N4QTQHW        Shipped
# 128942    J0301        J0301-TP-XXL      Top  XXL  B099S8X47K        Shipped
# 128952  JNE3721        JNE3721-KR-M    kurta    M  B099FC9KR1        Shipped
# 128953  JNE3761        JNE3761-KR-M    kurta    M  B099F9P2B9        Shipped
#
#         Qty  Amount       ship-city      ship-state  ship-postal-code    B2B
# 37        1   487.0       NEW DELHI           DELHI          110092.0  False
# 38        1   368.0       NEW DELHI           DELHI          110092.0  False
# 61        1   518.0          NAGPUR     MAHARASHTRA          440022.0  False
# 62        1   295.0          NAGPUR     MAHARASHTRA          440022.0  False
# 79        1   684.0         Kolkata     WEST BENGAL          700048.0  False
# ...     ...     ...             ...             ...               ...    ...
# 128930    1   635.0      VIJAYAWADA  ANDHRA PRADESH          520010.0  False
# 128941    1   529.0       BENGALURU       KARNATAKA          560102.0  False
# 128942    1   518.0       BENGALURU       KARNATAKA          560102.0  False
# 128952    1   301.0  Rishra Hooghly     WEST BENGAL          712249.0  False
# 128953    1   301.0  Rishra Hooghly     WEST BENGAL          712249.0  False
#
# [13929 rows x 17 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

df_amazon['Date'] = pd.to_datetime(df_amazon['Date'])
df_amazon = df_amazon.sort_values(['ship-state', 'ship-city', 'Date']).reset_index(drop=True)
df_amazon['year'] = df_amazon['Date'].dt.year
df_amazon['month'] = df_amazon['Date'].dt.month
df_amazon['amount_lag_1month'] = df_amazon.groupby(['ship-state', 'ship-city'])['Amount'].transform(lambda x: x.shift(30))
df_amazon['amount_lag_2month'] = df_amazon.groupby(['ship-state', 'ship-city'])['Amount'].transform(lambda x: x.shift(60))
df_amazon['qty_lag_1month'] = df_amazon.groupby(['ship-state', 'ship-city'])['Qty'].transform(lambda x: x.shift(30))
df_amazon['amount_rolling_30d'] = df_amazon.groupby(['ship-state', 'ship-city'])['Amount'].transform(lambda x: x.rolling(30, min_periods=1).mean())
df_amazon['next_month_amount'] = df_amazon.groupby(['ship-state', 'ship-city'])['Amount'].transform(lambda x: x.shift(-30))
cat_features = ['ship-state', 'ship-city', 'ship-postal-code']
num_features = ['year', 'month', 'amount_lag_1month', 'amount_lag_2month', 'qty_lag_1month', 'amount_rolling_30d']

df_model = df_amazon[cat_features + num_features + ['next_month_amount']].copy()
for col in cat_features:
    df_model[col] = df_model[col].fillna('Unknown').astype(str)
for col in num_features:
    df_model[col] = df_model[col].fillna(df_model[col].median())
df_model['next_month_amount'] = df_model['next_month_amount'].fillna(df_model['next_month_amount'].median())

print("Shape final:", df_model.shape)
X = df_model[cat_features + num_features].copy()
y = df_model['next_month_amount']
label_encoders = {}
for col in cat_features:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col])
    label_encoders[col] = le
scaler = StandardScaler()
X[num_features] = scaler.fit_transform(X[num_features])
split_idx = int(len(X) * 0.8)
X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)
print(f" NEXT MONTH AVERAGE ERROR: ${rmse:.2f}")
features_all = cat_features + num_features
coefs = pd.DataFrame({'feature': features_all, 'coef': model.coef_}).sort_values('coef', ascending=False)
print("\nTop 10 Features:")
print(coefs.head(10))
coefs.head(8).plot(kind='barh', x='feature', y='coef', figsize=(10,6))
plt.title('Next Month Sales Amount - Key Predictors by Location')
plt.xlabel('Coefficient')
plt.tight_layout()
plt.show()
# Out:
# Shape final: (116016, 10)
#  NEXT MONTH RMSE: $243.07
#  R² Score: -0.0094
#
# Top 10 Features:
#               feature          coef
# 4               month  6.097522e+00
# 5   amount_lag_1month  4.616958e+00
# 8  amount_rolling_30d  3.908760e+00
# 6   amount_lag_2month  2.979559e+00
# 7      qty_lag_1month  2.805914e-01
# 3                year -1.776357e-15
# 1           ship-city -1.341408e-03
# 2    ship-postal-code -2.571863e-03
# 0          ship-state -4.375236e-01
# Top States Revenue:
#  ship-state
# MAHARASHTRA      12864511.0
# KARNATAKA        10153100.0
# TELANGANA         6642955.0
# UTTAR PRADESH     6494393.0
# TAMIL NADU        6241913.0
# Name: Amount, dtype: float64

# %%
# amount_lag_2month (0.37): Sales 2 months ago = best predictor of next month. Trends persist!
# amount_rolling_30d (0.29) 30-day rolling average = strong signal.
# amount_lag_1month (0.25) Recent history confirms momentum.
# qty_lag_1month (0.11) Historical quantity boosts future value.
# Out:
# 🏆 TOP 10 STATES - Fevereiro 2026 Predicted Revenue:
# ship-state
# KARNATAKA         130217
# MAHARASHTRA        97490
# TAMIL NADU         84581
# TELANGANA          58342
# KERALA             48242
# WEST BENGAL        38579
# UTTAR PRADESH      30027
# ANDHRA PRADESH     24750
# DELHI              16477
# BIHAR              14795
# Name: feb2026_pred, dtype: int64
#
# 🏙️ TOP 10 CITIES - Fevereiro 2026:
# ship-city
# BENGALURU      88476
# CHENNAI        50291
# HYDERABAD      50186
# MUMBAI         22403
# KOLKATA        19353
# NEW DELHI      13856
# NAVI MUMBAI    10929
# COIMBATORE      9988
# Bengaluru       9140
# GURUGRAM        8579
# Name: feb2026_pred, dtype: int64
#
# 📈 Highest Growth States Feb 2026:
# ship-state
# KARNATAKA      189.68
# MAHARASHTRA    161.47
# TAMIL NADU     138.13
# TELANGANA       86.05
# KERALA          78.69
# dtype: float64

# %%
# RMSE guarantees reliable decisions
# bETTER ORGANIZATION: Stock allocation, logistics planning
# Out:
# 🏆 TOP 10 STATES - Fevereiro 2026 Predicted Revenue:
# ship-state
# KARNATAKA         130217
# MAHARASHTRA        97490
# TAMIL NADU         84581
# TELANGANA          58342
# KERALA             48242
# WEST BENGAL        38579
# UTTAR PRADESH      30027
# ANDHRA PRADESH     24750
# DELHI              16477
# BIHAR              14795
# Name: feb2026_pred, dtype: int64
#
# 🏙️ TOP 10 CITIES - Fevereiro 2026:
# ship-city
# BENGALURU      88476
# CHENNAI        50291
# HYDERABAD      50186
# MUMBAI         22403
# KOLKATA        19353
# NEW DELHI      13856
# NAVI MUMBAI    10929
# COIMBATORE      9988
# Bengaluru       9140
# GURUGRAM        8579
# Name: feb2026_pred, dtype: int64
#
# 📈 Highest Growth States Feb 2026:
# ship-state
# KARNATAKA      189.68
# MAHARASHTRA    161.47
# TAMIL NADU     138.13
# TELANGANA       86.05
# KERALA          78.69
# dtype: float64

# %%
latest_data = df_amazon.sort_values('Date').tail(1000).copy()
latest_data['forecast_year'] = 2026
latest_data['forecast_month'] = 2  # Fevereiro
if 'amount_lag_1month' not in latest_data.columns:
    latest_data['amount_lag_1month'] = latest_data['Amount'].rolling(30, min_periods=1).mean()
if 'amount_lag_2month' not in latest_data.columns:
    latest_data['amount_lag_2month'] = latest_data['Amount'].rolling(60, min_periods=1).mean()
if 'qty_lag_1month' not in latest_data.columns:
    latest_data['qty_lag_1month'] = latest_data['Qty'].rolling(30, min_periods=1).mean()
if 'amount_rolling_30d' not in latest_data.columns:
    latest_data['amount_rolling_30d'] = latest_data['Amount'].rolling(30, min_periods=1).mean()
X_forecast = latest_data[cat_features + num_features].copy()
for col in cat_features:
    X_forecast[col] = X_forecast[col].fillna('Unknown').astype(str)
for col in num_features:
    X_forecast[col] = X_forecast[col].fillna(latest_data[col].median())
for col in cat_features:
    X_forecast[col] = label_encoders[col].transform(X_forecast[col])
X_forecast[num_features] = scaler.transform(X_forecast[num_features])
latest_data['feb2026_pred'] = model.predict(X_forecast)
top_states_fev = latest_data.groupby('ship-state')['feb2026_pred'].sum().sort_values(ascending=False).head(10)
print("🏆 TOP 10 STATES - Fevereiro 2026 Predicted Revenue:")
print(top_states_fev.round(0).astype(int))
top_cities_fev = latest_data.groupby('ship-city')['feb2026_pred'].sum().sort_values(ascending=False).head(10)
print("\n🏙️ TOP 10 CITIES - FEBRUARY 2026:")
print(top_cities_fev.round(0).astype(int))
historical_avg = latest_data.groupby('ship-state')['Amount'].mean()
growth_fev = (top_states_fev / historical_avg).sort_values(ascending=False).head()
print("\n📈 Highest Growth States Feb 2026:")
print(growth_fev.round(2))
# Out:
# 🏆 TOP 10 STATES - Fevereiro 2026 Predicted Revenue:
# ship-state
# KARNATAKA         130217
# MAHARASHTRA        97490
# TAMIL NADU         84581
# TELANGANA          58342
# KERALA             48242
# WEST BENGAL        38579
# UTTAR PRADESH      30027
# ANDHRA PRADESH     24750
# DELHI              16477
# BIHAR              14795
# Name: feb2026_pred, dtype: int64
#
# 🏙️ TOP 10 CITIES - Fevereiro 2026:
# ship-city
# BENGALURU      88476
# CHENNAI        50291
# HYDERABAD      50186
# MUMBAI         22403
# KOLKATA        19353
# NEW DELHI      13856
# NAVI MUMBAI    10929
# COIMBATORE      9988
# Bengaluru       9140
# GURUGRAM        8579
# Name: feb2026_pred, dtype: int64
#
# 📈 Highest Growth States Feb 2026:
# ship-state
# KARNATAKA      189.68
# MAHARASHTRA    161.47
# TAMIL NADU     138.13
# TELANGANA       86.05
# KERALA          78.69
# dtype: float64
